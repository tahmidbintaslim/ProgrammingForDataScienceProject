# %%
#import numpy
import numpy as np

# %%
# import pandas
import pandas as pd

# %%
#import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
student_data = pd.read_csv(r"C:\Users\tahmi\Documents\GitHub\ProgrammingForDataScienceProject\Data\global.1751_2014.csv")
print(student_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-f8ec6f1f6e0c> in <module>
# ----> 1 student_data = pd.read_csv(r"C:\Users\tahmi\Documents\GitHub\ProgrammingForDataScienceProject\Data\global.1751_2014.csv")
#       2 print(student_data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File C:\Users\tahmi\Documents\GitHub\ProgrammingForDataScienceProject\Data\global.1751_2014.csv does not exist: 'C:\\Users\\tahmi\\Documents\\GitHub\\ProgrammingForDataScienceProject\\Data\\global.1751_2014.csv'

# %%
student_data = pd.read_csv(r"C:\Users\tahmi\Documents\GitHub\ProgrammingForDataScienceProject\Data\nation.1751_2014.csv")
print(student_data)
# Out:
#                                                   Nation    Year  \
# 0                  (Note: missing values denoted by ".")     NaN
# 1      Source: Tom Boden and Bob Andres (Oak Ridge Na...     NaN
# 2                         DOI: 10.3334/CDIAC/00001_V2017     NaN
# 3                                            AFGHANISTAN  1949.0
# 4                                            AFGHANISTAN  1950.0
# ...                                                  ...     ...
# 17230                                           ZIMBABWE  2010.0
# 17231                                           ZIMBABWE  2011.0
# 17232                                           ZIMBABWE  2012.0
# 17233                                           ZIMBABWE  2013.0
# 17234                                           ZIMBABWE  2014.0
#
#        Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    4.0
# 4                                                   23.0
# ...                                                  ...
# 17230                                             2121.0
# 17231                                             2608.0
# 17232                                             2125.0
# 17233                                             3184.0
# 17234                                             3278.0
#
#       Emissions from solid fuel consumption  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                         4
# 4                                         6
# ...                                     ...
# 17230                                  1531
# 17231                                  1584
# 17232                                   917
# 17233                                  1902
# 17234                                  2097
#
#       Emissions from liquid fuel consumption  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                          0
# 4                                         18
# ...                                      ...
# 17230                                    481
# 17231                                    888
# 17232                                   1006
# 17233                                   1119
# 17234                                   1005
#
#       Emissions from gas fuel consumption  Emissions from cement production  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                       0                               0.0
# 4                                       0                               0.0
# ...                                   ...                               ...
# 17230                                   0                             109.0
# 17231                                   0                             136.0
# 17232                                   0                             201.0
# 17233                                   0                             162.0
# 17234                                   0                             177.0
#
#       Emissions from gas flaring  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                              .
# 4                              0
# ...                          ...
# 17230                          0
# 17231                          0
# 17232                          0
# 17233                          0
# 17234                          0
#
#       Per capita CO2 emissions (metric tons of carbon)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                    .
# 4                                                    0
# ...                                                ...
# 17230                                             0.15
# 17231                                             0.18
# 17232                                             0.15
# 17233                                             0.21
# 17234                                             0.22
#
#        Emissions from bunker fuels (not included in the totals)
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    0.0
# 4                                                    0.0
# ...                                                  ...
# 17230                                                7.0
# 17231                                                8.0
# 17232                                                9.0
# 17233                                                9.0
# 17234                                                9.0
#
# [17235 rows x 10 columns]

# %%
student_data = pd.read_csv(r"C:\Users\tahmi\Documents\GitHub\ProgrammingForDataScienceProject\Data\region.1751_2014.csv")
print(student_data)
# Out:
#                                                  Region    Year  \
# 0                 (Note: missing values denoted by ".")     NaN
# 1     Source: Tom Boden and Bob Andres (Oak Ridge Na...     NaN
# 2                        DOI: 10.3334/CDIAC/00001_V2017     NaN
# 3                                                Africa  1884.0
# 4                                                Africa  1885.0
# ...                                                 ...     ...
# 1766                                     Western Europe  2010.0
# 1767                                     Western Europe  2011.0
# 1768                                     Western Europe  2012.0
# 1769                                     Western Europe  2013.0
# 1770                                     Western Europe  2014.0
#
#       Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   6.0
# 4                                                  10.0
# ...                                                 ...
# 1766                                           667268.0
# 1767                                           632301.0
# 1768                                           619795.0
# 1769                                           602876.0
# 1770                                           563225.0
#
#       Emissions from solid fuel consumption  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       6.0
# 4                                      10.0
# ...                                     ...
# 1766                               125875.0
# 1767                               130799.0
# 1768                               140965.0
# 1769                               132845.0
# 1770                               118701.0
#
#       Emissions from liquid fuel consumption  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        0.0
# 4                                        0.0
# ...                                      ...
# 1766                                315334.0
# 1767                                300858.0
# 1768                                286796.0
# 1769                                282017.0
# 1770                                277035.0
#
#       Emissions from gas fuel consumption  Emissions from cement production  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     0.0                               0.0
# 4                                     0.0                               0.0
# ...                                   ...                               ...
# 1766                             206649.0                           18250.0
# 1767                             182049.0                           17635.0
# 1768                             176101.0                           15048.0
# 1769                             172278.0                           14788.0
# 1770                             152034.0                           14580.0
#
#       Emissions from gas flaring  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            0.0
# 4                            0.0
# ...                          ...
# 1766                      1159.0
# 1767                       960.0
# 1768                       885.0
# 1769                       948.0
# 1770                       874.0
#
#      Per capita CO2 emissions (metric tons of carbon)
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                   .
# 4                                                   .
# ...                                               ...
# 1766                                              1.9
# 1767                                              1.8
# 1768                                             1.75
# 1769                                              1.7
# 1770                                             1.59
#
# [1771 rows x 9 columns]

# %%
data = pd.read_csv(r"C:\Users\Lenovo\Documents\GitHub\ProgrammingForDataScienceProject\Data\global.1751_2014.csv")
print(data)
# Out:
#      Year  \
# 0    1751
# 1    1752
# 2    1753
# 3    1754
# 4    1755
# ..    ...
# 259  2010
# 260  2011
# 261  2012
# 262  2013
# 263  2014
#
#      Total carbon emissions from fossil fuel consumption and cement production (million metric tons of C)  \
# 0                                                    3
# 1                                                    3
# 2                                                    3
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 259                                               9128
# 260                                               9503
# 261                                               9673
# 262                                               9773
# 263                                               9855
#
#      Carbon emissions from gas fuel consumption  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
# ..                                          ...
# 259                                        1696
# 260                                        1756
# 261                                        1783
# 262                                        1806
# 263                                        1823
#
#      Carbon emissions from liquid fuel consumption  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ..                                             ...
# 259                                           3107
# 260                                           3134
# 261                                           3200
# 262                                           3220
# 263                                           3280
#
#      Carbon emissions from solid fuel consumption  \
# 0                                               3
# 1                                               3
# 2                                               3
# 3                                               3
# 4                                               3
# ..                                            ...
# 259                                          3812
# 260                                          4055
# 261                                          4106
# 262                                          4126
# 263                                          4117
#
#      Carbon emissions from cement production  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ..                                       ...
# 259                                      446
# 260                                      494
# 261                                      519
# 262                                      554
# 263                                      568
#
#      Carbon emissions from gas flaring  \
# 0                                    0
# 1                                    0
# 2                                    0
# 3                                    0
# 4                                    0
# ..                                 ...
# 259                                 67
# 260                                 64
# 261                                 65
# 262                                 68
# 263                                 68
#
#      Per capita carbon emissions (metric tons of carbon; after 1949 only)
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 259                                               1.32
# 260                                               1.36
# 261                                               1.36
# 262                                               1.36
# 263                                               1.36
#
# [264 rows x 8 columns]
