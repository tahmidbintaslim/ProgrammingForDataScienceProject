# %%
#Import Libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\tahmi\Documents\GitHub\ProgrammingForDataScienceProject\Data\global.1751_2014.csv")
print(data)
# Out:
#      Year  \
# 0    1751
# 1    1752
# 2    1753
# 3    1754
# 4    1755
# ..    ...
# 259  2010
# 260  2011
# 261  2012
# 262  2013
# 263  2014
#
#      Total carbon emissions from fossil fuel consumption and cement production (million metric tons of C)  \
# 0                                                    3
# 1                                                    3
# 2                                                    3
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 259                                               9128
# 260                                               9503
# 261                                               9673
# 262                                               9773
# 263                                               9855
#
#      Carbon emissions from gas fuel consumption  \
# 0                                             0
# ...

# %%
data.head(10)
# Out:
#    Year  \
# 0  1751
# 1  1752
# 2  1753
# 3  1754
# 4  1755
# 5  1756
# 6  1757
# 7  1758
# 8  1759
# 9  1760
#
#    Total carbon emissions from fossil fuel consumption and cement production (million metric tons of C)  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
# 5                                                  3
# 6                                                  3
# 7                                                  3
# 8                                                  3
# 9                                                  3
#
#    Carbon emissions from gas fuel consumption  \
# 0                                           0
# 1                                           0
# 2                                           0
# ...

# %%
#return size of rows and cols
data.shape
# Out:
# (264, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=264, step=1)

# %%
data.columns
# Out:
# Index(['Year',
#        'Total carbon emissions from fossil fuel consumption and cement production (million metric tons of C)',
#        'Carbon emissions from gas fuel consumption',
#        'Carbon emissions from liquid fuel consumption',
#        'Carbon emissions from solid fuel consumption',
#        'Carbon emissions from cement production',
#        'Carbon emissions from gas flaring',
#        'Per capita carbon emissions (metric tons of carbon; after 1949 only)'],
#       dtype='object')

# %%
data.loc[0]
# Out:
# Year                                                                                                    1751.0
# Total carbon emissions from fossil fuel consumption and cement production (million metric tons of C)       3.0
# Carbon emissions from gas fuel consumption                                                                 0.0
# Carbon emissions from liquid fuel consumption                                                              0.0
# Carbon emissions from solid fuel consumption                                                               3.0
# Carbon emissions from cement production                                                                    0.0
# Carbon emissions from gas flaring                                                                          0.0
# Per capita carbon emissions (metric tons of carbon; after 1949 only)                                       NaN
# Name: 0, dtype: float64

# %%
data.dtypes
# Out:
# Year                                                                                                      int64
# Total carbon emissions from fossil fuel consumption and cement production (million metric tons of C)      int64
# Carbon emissions from gas fuel consumption                                                                int64
# Carbon emissions from liquid fuel consumption                                                             int64
# Carbon emissions from solid fuel consumption                                                              int64
# Carbon emissions from cement production                                                                   int64
# Carbon emissions from gas flaring                                                                         int64
# Per capita carbon emissions (metric tons of carbon; after 1949 only)                                    float64
# dtype: object

# %%
#find missing values
data.isna().sum()
# Out:
# Year                                                                                                      0
# Total carbon emissions from fossil fuel consumption and cement production (million metric tons of C)      0
# Carbon emissions from gas fuel consumption                                                                0
# Carbon emissions from liquid fuel consumption                                                             0
# Carbon emissions from solid fuel consumption                                                              0
# Carbon emissions from cement production                                                                   0
# Carbon emissions from gas flaring                                                                         0
# Per capita carbon emissions (metric tons of carbon; after 1949 only)                                    199
# dtype: int64

# %% [markdown]
# There is missing values in our global dataset

# %%
#data is numeric, fill missing values with mean
data['Per capita carbon emissions (metric tons of carbon; after 1949 only)'].fillna(data['Per capita carbon emissions (metric tons of carbon; after 1949 only)'].mean(),inplace=True)

# %%
#There is no missing values
data.isna().sum()
# Out:
# Year                                                                                                    0
# Total carbon emissions from fossil fuel consumption and cement production (million metric tons of C)    0
# Carbon emissions from gas fuel consumption                                                              0
# Carbon emissions from liquid fuel consumption                                                           0
# Carbon emissions from solid fuel consumption                                                            0
# Carbon emissions from cement production                                                                 0
# Carbon emissions from gas flaring                                                                       0
# Per capita carbon emissions (metric tons of carbon; after 1949 only)                                    0
# dtype: int64

# %%
data.notnull()
# Out:
#      Year  \
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# ..    ...
# 259  True
# 260  True
# 261  True
# 262  True
# 263  True
#
#      Total carbon emissions from fossil fuel consumption and cement production (million metric tons of C)  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 259                                               True
# 260                                               True
# 261                                               True
# 262                                               True
# 263                                               True
#
#      Carbon emissions from gas fuel consumption  \
# 0                                          True
# ...

# %%
data.describe()
# Out:
#               Year  \
# count   264.000000
# mean   1882.500000
# std      76.354437
# min    1751.000000
# 25%    1816.750000
# 50%    1882.500000
# 75%    1948.250000
# max    2014.000000
#
#        Total carbon emissions from fossil fuel consumption and cement production (million metric tons of C)  \
# count                                         264.000000
# mean                                         1522.984848
# std                                          2444.152273
# min                                             3.000000
# 25%                                            13.750000
# 50%                                           264.000000
# 75%                                          1431.500000
# max                                          9855.000000
#
#        Carbon emissions from gas fuel consumption  \
# count                                  264.000000
# mean                                   209.166667
# std                                    439.181345
# ...

# %%
data['Total carbon emissions from fossil fuel consumption and cement production (million metric tons of C)'].hist(bins=40)
