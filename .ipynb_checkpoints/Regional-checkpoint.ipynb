# %%
#Import Libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\tahmi\Documents\GitHub\ProgrammingForDataScienceProject\Data\region.1751_2014.csv")
print(data)
# Out:
#                                                  Region    Year  \
# 0                 (Note: missing values denoted by ".")     NaN
# 1     Source: Tom Boden and Bob Andres (Oak Ridge Na...     NaN
# 2                        DOI: 10.3334/CDIAC/00001_V2017     NaN
# 3                                                Africa  1884.0
# 4                                                Africa  1885.0
# ...                                                 ...     ...
# 1766                                     Western Europe  2010.0
# 1767                                     Western Europe  2011.0
# 1768                                     Western Europe  2012.0
# 1769                                     Western Europe  2013.0
# 1770                                     Western Europe  2014.0
#
#       Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 0                                                   NaN
# ...

# %%
data.head(10)
# Out:
#                                               Region    Year  \
# 0              (Note: missing values denoted by ".")     NaN
# 1  Source: Tom Boden and Bob Andres (Oak Ridge Na...     NaN
# 2                     DOI: 10.3334/CDIAC/00001_V2017     NaN
# 3                                             Africa  1884.0
# 4                                             Africa  1885.0
# 5                                             Africa  1886.0
# 6                                             Africa  1887.0
# 7                                             Africa  1888.0
# 8                                             Africa  1889.0
# 9                                             Africa  1890.0
#
#    Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
#return size of rows and cols
data.shape
# Out:
# (1771, 9)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1771, step=1)

# %%
data.columns
# Out:
# Index(['Region', 'Year',
#        'Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)',
#        'Emissions from solid fuel consumption',
#        'Emissions from liquid fuel consumption',
#        'Emissions from gas fuel consumption',
#        'Emissions from cement production', 'Emissions from gas flaring',
#        'Per capita CO2 emissions (metric tons of carbon)'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Region                                                                                      object
# Year                                                                                       float64
# Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)    float64
# Emissions from solid fuel consumption                                                      float64
# Emissions from liquid fuel consumption                                                     float64
# Emissions from gas fuel consumption                                                        float64
# Emissions from cement production                                                           float64
# Emissions from gas flaring                                                                 float64
# Per capita CO2 emissions (metric tons of carbon)                                            object
# dtype: object

# %%
data.loc[0]
# Out:
# Region                                                                                     (Note: missing values denoted by ".")
# Year                                                                                                                         NaN
# Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)                                      NaN
# Emissions from solid fuel consumption                                                                                        NaN
# Emissions from liquid fuel consumption                                                                                       NaN
# Emissions from gas fuel consumption                                                                                          NaN
# Emissions from cement production                                                                                             NaN
# ...

# %%
#find missing values
data.isna().sum()
# Out:
# Region                                                                                     0
# Year                                                                                       3
# Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)    3
# Emissions from solid fuel consumption                                                      3
# Emissions from liquid fuel consumption                                                     3
# Emissions from gas fuel consumption                                                        3
# Emissions from cement production                                                           3
# Emissions from gas flaring                                                                 3
# Per capita CO2 emissions (metric tons of carbon)                                           3
# dtype: int64

# %%
data=data.replace(".","0")

# %%
data["Region"] = data["Region"].astype("string")

# %%
data["Year"] = pd.to_numeric(data["Year"],errors='coerce')

# %%
data["Per capita CO2 emissions (metric tons of carbon)"] = pd.to_numeric(data["Per capita CO2 emissions (metric tons of carbon)"],errors='coerce')

# %%
data.drop(data.index[[0,1,2]])
# Out:
#               Region    Year  \
# 3             Africa  1884.0
# 4             Africa  1885.0
# 5             Africa  1886.0
# 6             Africa  1887.0
# 7             Africa  1888.0
# ...              ...     ...
# 1766  Western Europe  2010.0
# 1767  Western Europe  2011.0
# 1768  Western Europe  2012.0
# 1769  Western Europe  2013.0
# 1770  Western Europe  2014.0
#
#       Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)  \
# 3                                                   6.0
# 4                                                  10.0
# 5                                                  13.0
# 6                                                  13.0
# 7                                                  22.0
# ...                                                 ...
# 1766                                           667268.0
# 1767                                           632301.0
# 1768                                           619795.0
# ...

# %%
#find missing values
data.isna().sum()
# Out:
# Region                                                                                     0
# Year                                                                                       3
# Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)    3
# Emissions from solid fuel consumption                                                      3
# Emissions from liquid fuel consumption                                                     3
# Emissions from gas fuel consumption                                                        3
# Emissions from cement production                                                           3
# Emissions from gas flaring                                                                 3
# Per capita CO2 emissions (metric tons of carbon)                                           3
# dtype: int64

# %%
data.dtypes
# Out:
# Region                                                                                      string
# Year                                                                                       float64
# Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)    float64
# Emissions from solid fuel consumption                                                      float64
# Emissions from liquid fuel consumption                                                     float64
# Emissions from gas fuel consumption                                                        float64
# Emissions from cement production                                                           float64
# Emissions from gas flaring                                                                 float64
# Per capita CO2 emissions (metric tons of carbon)                                           float64
# dtype: object
